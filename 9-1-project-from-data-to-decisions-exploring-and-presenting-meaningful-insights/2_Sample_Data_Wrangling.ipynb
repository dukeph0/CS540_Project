# %% [markdown]
# # Sample Data Wrangling
#
# For the module nine project you are required to produce coding samples for how you wrangled, ie cleaned, your dataset as one piece of your project submission. This Notebook is provided with some sample data wrangling from module two. You may copy examples from the code blocks herein to include in your final submission.
#
# <div class="alert alert-block alert-info">
#     <span style="color:black"><b><i>Activity Code Submission:</i></b> You will complete your assignment code in the <b>Module_Nine_Project.ipynb</b> Notebook file from the filetree on the left that is pre-templated for your modification in accordance with the assignment instructions.</span>
# </div>
#
# ### Data Source Information
# The sourcing information for the data sets can be found in the `README.md` file within the data folder.
#
# To use this sample script for your selected data set, you can copy the desired code blocks to the Module_Nine_Project Notebook that you will use for your project submission, or replace the sample data path below keeping in mind you will need to copy the items to the required Project Notebook for inclusion in your project submission.
#
# <div class="alert alert-block alert-success">
#     <span style="color:black"><b><i>To Begin:</i></b> replace the <mark>data/sample_use_only/titanic_raw.csv</mark> sample data path with the path to your selected data set.</span>
# </div>

# %%
reference_file = "data/sample_use_only/titanic_raw.csv"

# %% [markdown]
# ## Installing Required Packages
# If you have additional packages that you would like to use or install, add them to the **requirements.txt** file then run the next block.

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (25.1.1)

# %%
# !pip install -r sample_requirements.txt
# Out:
# Requirement already satisfied: ydata-profiling==4.16.1 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from -r sample_requirements.txt (line 1)) (4.16.1)
# Requirement already satisfied: openpyxl==3.1.3 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from -r sample_requirements.txt (line 2)) (3.1.3)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (1.10.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: pydantic>=2 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (2.11.4)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (0.8.1)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (1.24.2)
# Requirement already satisfied: htmlmin==0.1.12 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (2.30.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (0.14.4)
# Requirement already satisfied: typeguard<5,>=3 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (4.4.2)
# Requirement already satisfied: imagehash==4.3.1 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (0.61.0)
# Requirement already satisfied: et-xmlfile in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from openpyxl==3.1.3->-r sample_requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: PyWavelets in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from imagehash==4.3.1->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: pillow in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from imagehash==4.3.1->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from numba<=0.61,>=0.56.0->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from phik<0.13,>=0.11.1->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (2023.5.7)
# Requirement already satisfied: patsy>=0.5.6 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: typing_extensions>=4.10.0 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from typeguard<5,>=3->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (4.13.2)
# Requirement already satisfied: attrs>=19.3.0 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: puremagic in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (1.29)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: six>=1.5 in /home/codio/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling==4.16.1->-r sample_requirements.txt (line 1)) (1.16.0)

# %% [markdown]
# ## Import the Required Packages
# If you have additional packages that you would like to import, add them here.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading the Data
# After you have selected your data set that wish to wrangle, replace the reference file path in the code block at the top of this Notebook, then run the following block.

# %%
raw_data = pd.read_csv(reference_file)
raw_data.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Cleaning the Data
# The sections that follow have some pre-templated steps to examine and clean data. The columns or specified attributes will need to be replaced for your respective dataset that you are cleaning. You may also need to add different cleaning options from your reading as this provides an example starting point to work with your selected dataset.
#
# ***Remember to add comments as you go.***
#
# ## Columns
#
# <div class="alert alert-block alert-danger">
#     <span style="color:black"><b><i>Example Data:</i></b> Keep in mind that the column values are from the sample data and will not represent your dataset until these blocks are run.</span>
# </div>

# %%
raw_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Renaming Columns
# If any of the columns in your dataset need renamed, you can use the following examples to update your column names.
#
# <div class="alert alert-block alert-danger">
#     <span style="color:black"><b><i>Example Data:</i></b> Keep in mind that the column values selected below are from the sample data and will need replaced before running the block with your dataset.</span>
# </div>
#
# In the example below we want to rename the `PassengerId` column `ID` and the `Pclass` column to say `Class` as we are considering merging this data with another dataset later which will use these columns as shared keys. For this task, we use the `rename()` method and pass in a dictionary mapping the column names to their new names. We can pass `inplace=True` to change our original dataframe instead of getting a new one back, or `inplace=False` to create a new dataframe to compare against our original. In the example, we are creating a new dataframe that we will use for all follow-on cleaning actions.

# %%
clean_data = raw_data.rename(
    columns={
        'PassengerId': 'ID',
        'Pclass': 'Class'
    }, inplace=False
)
clean_data.head()
# Out:
#    ID  Survived  Class                                               Name
# 0   1         0      3                            Braund, Mr. Owen Harris  \
# 1   2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3         1      3                             Heikkinen, Miss. Laina
# 3   4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   5         0      3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Working with Missing Values
# Lets take a look at the output of `info()` method to get a quick view of additional information about the data set which can help pinpoint missing values and wrong data types.
#
#
# <div class="alert alert-block alert-danger">
#     <span style="color:black"><b><i>Example Data:</i></b> Keep in mind that the output below are from the sample data and will need replaced before running the block with your dataset.</span>
# </div>
#
# In the example dataset, we have an index range of 891 entries or rows available in the sample dataset. Using that foundational data, we can examine the null counts to identify which columns may have null, missing or NaN values. In the example dataset, the following columns indicate potential issues in the data: Age, Cabin, and Embarked.

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        891 non-null    int64
#  1   Survived  891 non-null    int64
#  2   Class     891 non-null    int64
#  3   Name      891 non-null    object
#  4   Sex       891 non-null    object
#  5   Age       714 non-null    float64
#  6   SibSp     891 non-null    int64
#  7   Parch     891 non-null    int64
#  8   Ticket    891 non-null    object
#  9   Fare      891 non-null    float64
#  10  Cabin     204 non-null    object
#  11  Embarked  889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### isnull()
# We can also use the `isnull()` method to return a dataframe of boolean values where **True** represents missing data.

# %%
clean_data.isnull()
# Out:
#         ID  Survived  Class   Name    Sex    Age  SibSp  Parch  Ticket   Fare
# 0    False     False  False  False  False  False  False  False   False  False  \
# 1    False     False  False  False  False  False  False  False   False  False
# 2    False     False  False  False  False  False  False  False   False  False
# 3    False     False  False  False  False  False  False  False   False  False
# 4    False     False  False  False  False  False  False  False   False  False
# ..     ...       ...    ...    ...    ...    ...    ...    ...     ...    ...
# 886  False     False  False  False  False  False  False  False   False  False
# 887  False     False  False  False  False  False  False  False   False  False
# 888  False     False  False  False  False   True  False  False   False  False
# 889  False     False  False  False  False  False  False  False   False  False
# 890  False     False  False  False  False  False  False  False   False  False
#
#      Cabin  Embarked
# 0     True     False
# 1    False     False
# 2     True     False
# 3    False     False
# 4     True     False
# ..     ...       ...
# 886   True     False
# 887  False     False
# 888   True     False
# 889  False     False
# 890   True     False
#
# [891 rows x 12 columns]

# %% [markdown]
# For the example dataset, since we already saw from the `info()` method that only three columns were impacted by data issues, the output of the `isnull()` method may not be as helpful so we can limit the output for a given column to check for nulls or use the output for other cleaning functions as shown in the example below.
#
# For your selected dataset, you can replace the Column name `Age` with your selected column that you would like to assess expanding on the dataset for additional afflicted columns for cleaning.

# %%
bool_series = pd.isnull(clean_data["Age"])
missing_age_data = clean_data[bool_series]
missing_age_data
# Out:
#       ID  Survived  Class                                      Name     Sex
# 5      6         0      3                          Moran, Mr. James    male  \
# 17    18         1      2              Williams, Mr. Charles Eugene    male
# 19    20         1      3                   Masselmani, Mrs. Fatima  female
# 26    27         0      3                   Emir, Mr. Farred Chehab    male
# 28    29         1      3             O'Dwyer, Miss. Ellen "Nellie"  female
# ..   ...       ...    ...                                       ...     ...
# 859  860         0      3                          Razi, Mr. Raihed    male
# 863  864         0      3         Sage, Miss. Dorothy Edith "Dolly"  female
# 868  869         0      3               van Melkebeke, Mr. Philemon    male
# 878  879         0      3                        Laleff, Mr. Kristo    male
# 888  889         0      3  Johnston, Miss. Catherine Helen "Carrie"  female
#
#      Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 5    NaN      0      0      330877   8.4583   NaN        Q
# 17   NaN      0      0      244373  13.0000   NaN        S
# 19   NaN      0      0        2649   7.2250   NaN        C
# 26   NaN      0      0        2631   7.2250   NaN        C
# 28   NaN      0      0      330959   7.8792   NaN        Q
# ..   ...    ...    ...         ...      ...   ...      ...
# 859  NaN      0      0        2629   7.2292   NaN        C
# 863  NaN      8      2    CA. 2343  69.5500   NaN        S
# 868  NaN      0      0      345777   9.5000   NaN        S
# 878  NaN      0      0      349217   7.8958   NaN        S
# 888  NaN      1      2  W./C. 6607  23.4500   NaN        S
#
# [177 rows x 12 columns]

# %% [markdown]
# ### Using Numpy to Find Missing Data using a Dictionary Comprehension
# Rather than do this for each column, we can write a function that will use a [dictionary comprehension](https://www.python.org/dev/peps/pep-0274/) to check all the columns for us:

# %%
def get_nan_count(clean_data):
    return {
        col: clean_data[clean_data[col].isin([np.nan])].shape[0] for col in clean_data.columns
    }

get_nan_count(clean_data)
# Out:
# {'ID': 0,
#  'Survived': 0,
#  'Class': 0,
#  'Name': 0,
#  'Sex': 0,
#  'Age': 177,
#  'SibSp': 0,
#  'Parch': 0,
#  'Ticket': 0,
#  'Fare': 0,
#  'Cabin': 687,
#  'Embarked': 2}

# %% [markdown]
# ###  Filling Missing Values Using fillna(), replace() and interpolate()
# From the example output, there were 177 rows of data that were impacted by missing data from the sample dataset. For your selected dataset you should evaluate your columns you identified with missing or null values and expand to the afflicted columns to clean your respective dataset.
#
# #### Filling Missing Values with a Specific Value Using fillna()
# Here in the example, we will fill in the missing `Age` values with an age of `0` based on dataset knowledge, you will make your own decisions for how you handle your missing data and justify your decisions as part of your activity reflection.

# %%
clean_data["Age"].fillna('0', inplace = True )
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        891 non-null    int64
#  1   Survived  891 non-null    int64
#  2   Class     891 non-null    int64
#  3   Name      891 non-null    object
#  4   Sex       891 non-null    object
#  5   Age       891 non-null    object
#  6   SibSp     891 non-null    int64
#  7   Parch     891 non-null    int64
#  8   Ticket    891 non-null    object
#  9   Fare      891 non-null    float64
#  10  Cabin     204 non-null    object
#  11  Embarked  889 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 83.7+ KB

# %% [markdown]
# If you do not find the info() method helpful to find the missing data, you can use the previously created get_nan_count() we created to view the missing data by column. In the sample dataset you will see there are still two columns with null values to be addressed.

# %%
get_nan_count(clean_data)
# Out:
# {'ID': 0,
#  'Survived': 0,
#  'Class': 0,
#  'Name': 0,
#  'Sex': 0,
#  'Age': 0,
#  'SibSp': 0,
#  'Parch': 0,
#  'Ticket': 0,
#  'Fare': 0,
#  'Cabin': 687,
#  'Embarked': 2}

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <span style="color:black"><b><i>Example Data:</i></b> Your selected dataset is likely to have several columns where the data is missing, create additional code blocks as necessary to clean your data according to the assignment requirements. Here we will clean the columns with different methods to show you different use cases, you will modify the code herein to the methods you feel are appropriate for your selected data set.
# </div>

# %% [markdown]
# #### Replacing Missing Values Using replace()
# Here in the example, we will replace the missing `Embarked` values with an age of `U` to represent **Unknown** based on dataset knowledge, you will make your own decisions for how you handle your missing data and justify your decisions as part of your activity reflection.

# %%
clean_data["Embarked"].replace(to_replace=np.nan, value='U', inplace = True )
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        891 non-null    int64
#  1   Survived  891 non-null    int64
#  2   Class     891 non-null    int64
#  3   Name      891 non-null    object
#  4   Sex       891 non-null    object
#  5   Age       891 non-null    object
#  6   SibSp     891 non-null    int64
#  7   Parch     891 non-null    int64
#  8   Ticket    891 non-null    object
#  9   Fare      891 non-null    float64
#  10  Cabin     204 non-null    object
#  11  Embarked  891 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 83.7+ KB

# %% [markdown]
# #### Dropping Missing Values in Pandas Using dropna()
# Here in the example, we will drop the column `Cabin` based on dataset knowledge, you will make your own decisions for how you handle your missing data and justify your decisions as part of your activity reflection. Keep in mind that if you use dropna() with an axis of 1, where there are nulls or missing values in more than one column, it may drop all columns that have null or missing values.

# %%
clean_data.dropna(axis=1, inplace = True )
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        891 non-null    int64
#  1   Survived  891 non-null    int64
#  2   Class     891 non-null    int64
#  3   Name      891 non-null    object
#  4   Sex       891 non-null    object
#  5   Age       891 non-null    object
#  6   SibSp     891 non-null    int64
#  7   Parch     891 non-null    int64
#  8   Ticket    891 non-null    object
#  9   Fare      891 non-null    float64
#  10  Embarked  891 non-null    object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 76.7+ KB

# %% [markdown]
# ### Duplicated Records
# Some datasets may include duplicated records.
#
# <div class="alert alert-block alert-danger">
#     <span style="color:black"><b><i>Example Data:</i></b> Keep in mind that the data types are from the sample data and will not represent your dataset until these blocks are run.</span>
# </div>
#
# The sample dataset does not have any duplicated records, though some code examples will be provided here for your use against your selected dataset, update the actions you would like to take against your selected dataset to clean it to your preference.

# %%
clean_data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %% [markdown]
# ## Data Types
# <div class="alert alert-block alert-danger">
#     <span style="color:black"><b><i>Example Data:</i></b> Keep in mind that the data types are from the sample data and will not represent your dataset until these blocks are run.</span>
# </div>
#
# You can use either the .dtypes property to view the data types for each column in the data frame, or the .info() method which will provide additional insights into the columns.

# %%
clean_data.dtypes
# Out:
# ID            int64
# Survived      int64
# Class         int64
# Name         object
# Sex          object
# Age          object
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Embarked     object
# dtype: object

# %% [markdown]
# ### Data Type Conversion
# If any of the data types in your dataset need to be modified or redefined, you can use the following block to update your column data types.
#
# <div class="alert alert-block alert-danger">
#     <span style="color:black"><b><i>Example Data:</i></b> Keep in mind that the columns and data types selected below are from the sample data and will need replaced before running the block with your dataset.</span>
# </div>
#
# In the example below we want to modify the data values and type for the `Survived` column to represent a `bool`.
#
# If you do not have any type conversions required for your data set, feel free to comment out the existing example and add a comment as applicable in the code block below:

# %%
clean_data = clean_data.assign(
    Survived=lambda x: x.Survived.astype('bool')
)
clean_data.dtypes
# Out:
# ID            int64
# Survived       bool
# Class         int64
# Name         object
# Sex          object
# Age          object
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Embarked     object
# dtype: object

# %% [markdown]
# We will take a quick look at the output of the describe method.

# %%
clean_data.describe()
# Out:
#                ID       Class       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean   446.000000    2.308642    0.523008    0.381594   32.204208
# std    257.353842    0.836071    1.102743    0.806057   49.693429
# min      1.000000    1.000000    0.000000    0.000000    0.000000
# 25%    223.500000    2.000000    0.000000    0.000000    7.910400
# 50%    446.000000    3.000000    0.000000    0.000000   14.454200
# 75%    668.500000    3.000000    1.000000    0.000000   31.000000
# max    891.000000    3.000000    8.000000    6.000000  512.329200

# %% [markdown]
# We will now take a look at the top five records in our dataframe before continue the cleaning examples.

# %%
clean_data.head()
# Out:
#    ID  Survived  Class                                               Name
# 0   1     False      3                            Braund, Mr. Owen Harris  \
# 1   2      True      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3      True      3                             Heikkinen, Miss. Laina
# 3   4      True      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   5     False      3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500        S
# 1  female  38.0      1      0          PC 17599  71.2833        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250        S
# 3  female  35.0      1      0            113803  53.1000        S
# 4    male  35.0      0      0            373450   8.0500        S

# %% [markdown]
# ### Categoricals
# When choosing which columns to set as categories, you will want to evaluate how many different values are available for the column.
# <div class="alert alert-block alert-danger">
#     <span style="color:black"><b><i>Example Data:</i></b> Keep in mind that the output are from the sample data and will not represent your dataset until these blocks are run.</span>
# </div>
#
# Here in the example dataset, there are three values for the `Class` column, there are two values for the `Sex` column, and three values for the `Embarked` column, so we will convert those to categories for furture analysis. All other columns aside from `Survived` column that we converted to a bool, have a variety of values which cannot be easily placed into categories without first creating bins to use as categoricals which will we learn more about in the coming modules.

# %%
clean_data_with_categories = clean_data.assign(
    Class=clean_data.Class.astype('category'),
    Sex=clean_data.Sex.astype('category'),
    Embarked=clean_data.Embarked.astype('category')
)
clean_data_with_categories.dtypes
# Out:
# ID             int64
# Survived        bool
# Class       category
# Name          object
# Sex         category
# Age           object
# SibSp          int64
# Parch          int64
# Ticket        object
# Fare         float64
# Embarked    category
# dtype: object

# %%
clean_data_with_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        891 non-null    int64
#  1   Survived  891 non-null    bool
#  2   Class     891 non-null    category
#  3   Name      891 non-null    object
#  4   Sex       891 non-null    category
#  5   Age       891 non-null    object
#  6   SibSp     891 non-null    int64
#  7   Parch     891 non-null    int64
#  8   Ticket    891 non-null    object
#  9   Fare      891 non-null    float64
#  10  Embarked  891 non-null    category
# dtypes: bool(1), category(3), float64(1), int64(3), object(3)
# memory usage: 52.8+ KB

# %%
clean_data_with_categories.describe()
# Out:
#                ID       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000
# mean   446.000000    0.523008    0.381594   32.204208
# std    257.353842    1.102743    0.806057   49.693429
# min      1.000000    0.000000    0.000000    0.000000
# 25%    223.500000    0.000000    0.000000    7.910400
# 50%    446.000000    0.000000    0.000000   14.454200
# 75%    668.500000    1.000000    0.000000   31.000000
# max    891.000000    8.000000    6.000000  512.329200

# %%
clean_data_with_categories.describe(include='category')
# Out:
#         Class   Sex Embarked
# count     891   891      891
# unique      3     2        4
# top         3  male        S
# freq      491   577      644

# %% [markdown]
# ## Tabular Format
# <div class="alert alert-block alert-danger">
#     <span style="color:black"><b><i>Example Data:</i></b> Keep in mind that the output are from the sample data and will not represent your dataset until these blocks are run. Validate your table represents your dataset before activity submission.</span>
# </div>

# %%
len(clean_data_with_categories)
# Out:
# 891

# %%
pd.set_option('display.max_rows', None)
clean_data_with_categories
# Out:
#       ID  Survived Class                                               Name
# 0      1     False     3                            Braund, Mr. Owen Harris  \
# 1      2      True     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3      True     3                             Heikkinen, Miss. Laina
# 3      4      True     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5     False     3                           Allen, Mr. William Henry
# 5      6     False     3                                   Moran, Mr. James
# 6      7     False     1                            McCarthy, Mr. Timothy J
# 7      8     False     3                     Palsson, Master. Gosta Leonard
# 8      9      True     3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9     10      True     2                Nasser, Mrs. Nicholas (Adele Achem)
# 10    11      True     3                    Sandstrom, Miss. Marguerite Rut
# 11    12      True     1                           Bonnell, Miss. Elizabeth
# 12    13     False     3                     Saundercock, Mr. William Henry
# 13    14     False     3                        Andersson, Mr. Anders Johan
# 14    15     False     3               Vestrom, Miss. Hulda Amanda Adolfina
# 15    16      True     2                   Hewlett, Mrs. (Mary D Kingcome)
# 16    17     False     3                               Rice, Master. Eugene
# 17    18      True     2                       Williams, Mr. Charles Eugene
# 18    19     False     3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 
# 581  582      True     1  Thayer, Mrs. John Borland (Marian Longstreth M...
# 582  583     False     2                         Downton, Mr. William James
# 583  584     False     1                                Ross, Mr. John Hugo
# 584  585     False     3                                Paulner, Mr. Uscher
# 585  586      True     1                                Taussig, Miss. Ruth
# 586  587     False     2                            Jarvis, Mr. John Denzil
# 587  588      True     1                   Frolicher-Stehli, Mr. Maxmillian
# 588  589     False     3                              Gilinski, Mr. Eliezer
# 589  590     False     3                                Murdlin, Mr. Joseph
# 590  591     False     3                               Rintamaki, Mr. Matti
# 591  592      True     1    Stephenson, Mrs. Walter Bertram (Martha Eustis)
# 592  593     False     3                         Elsbury, Mr. William James
# 593  594     False     3                                 Bourke, Miss. Mary
# 594  595     False     2                            Chapman, Mr. John Henry
# 595  596     False     3                        Van Impe, Mr. Jean Baptiste
# 596  597      True     2                         Leitch, Miss. Jessie Wills
# 597  598     False     3                                Johnson, Mr. Alfred
# 598  599     False     3                                  Boulos, Mr. Hanna
# 599  600      True     1       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")
# 600  601      True     2  Jacobsohn, Mrs. Sidney Samuel (Amy Frances Chr...
# 601  602     False     3                               Slabenoff, Mr. Petco
# 602  603     False     1                          Harrington, Mr. Charles H
# 603  604     False     3                          Torber, Mr. Ernst William
# 604  605      True     1                    Homer, Mr. Harry ("Mr E Haven")
# 605  606     False     3                      Lindell, Mr. Edvard Bengtsson
# ...
# 672    male  70.0      0      0          C.A. 24580   10.5000        S
# 673    male  31.0      0      0              244270   13.0000        S
# 674    male     0      0      0              239856    0.0000        S
# 675    male  18.0      0      0              349912    7.7750        S
# 676    male  24.5      0      0              342826    8.0500        S
# 677  female  18.0      0      0                4138    9.8417        S
# 678  female  43.0      1      6             CA 2144   46.9000        S
# 679    male  36.0      0      1            PC 17755  512.3292        C
# 680  female     0      0      0              330935    8.1375        Q
# 681    male  27.0      0      0            PC 17572   76.7292        C
# 682    male  20.0      0      0                6563    9.2250        S
# 683    male  14.0      5      2             CA 2144   46.9000        S
# 684    male  60.0      1      1               29750   39.0000        S
# 685    male  25.0      1      2       SC/Paris 2123   41.5792        C
# 686    male  14.0      4      1             3101295   39.6875        S
# 687    male  19.0      0      0              349228   10.1708        S
# 688    male  18.0      0      0              350036    7.7958        S
# 689  female  15.0      0      1               24160  211.3375        S
# 690    male  31.0      1      0               17474   57.0000        S
# 691  female   4.0      0      1              349256   13.4167        C
# 692    male     0      0      0                1601   56.4958        S
# 693    male  25.0      0      0                2672    7.2250        C
# 694    male  60.0      0      0              113800   26.5500        S
# 695    male  52.0      0      0              248731   13.5000        S
# 696    male  44.0      0      0              363592    8.0500        S
# 697  female     0      0      0               35852    7.7333        Q
# 698    male  49.0      1      1               17421  110.8833        C
# 699    male  42.0      0      0              348121    7.6500        S
# 700  female  18.0      1      0            PC 17757  227.5250        C
# 701    male  35.0      0      0            PC 17475   26.2875        S
# 702  female  18.0      0      1                2691   14.4542        C
# 703    male  25.0      0      0               36864    7.7417        Q
# 704    male  26.0      1      0              350025    7.8542        S
# 705    male  39.0      0      0              250655   26.0000        S
# 706  female  45.0      0      0              223596   13.5000        S
# 707    male  42.0      0      0            PC 17476   26.2875        S
# 708  female  22.0      0      0              113781  151.5500        S
# 709    male     0      1      1                2661   15.2458        C
# 710  female  24.0      0      0            PC 17482   49.5042        C
# 711    male     0      0      0              113028   26.5500        S
# 712    male  48.0      1      0               19996   52.0000        S
# 713    male  29.0      0      0                7545    9.4833        S
# 714    male  52.0      0      0              250647   13.0000        S
# 715    male  19.0      0      0              348124    7.6500        S
# 716  female  38.0      0      0            PC 17757  227.5250        C
# 717  female  27.0      0      0               34218   10.5000        S
# 718    male     0      0      0               36568   15.5000        Q
# 719    male  33.0      0      0              347062    7.7750        S
# 720  female   6.0      0      1              248727   33.0000        S
# 721    male  17.0      1      0              350048    7.0542        S
# 722    male  34.0      0      0               12233   13.0000        S
# 723    male  50.0      0      0              250643   13.0000        S
# 724    male  27.0      1      0              113806   53.1000        S
# 725    male  20.0      0      0              315094    8.6625        S
# 726  female  30.0      3      0               31027   21.0000        S
# 727  female     0      0      0               36866    7.7375        Q
# 728    male  25.0      1      0              236853   26.0000        S
# 729  female  25.0      1      0    STON/O2. 3101271    7.9250        S
# 730  female  29.0      0      0               24160  211.3375        S
# 731    male  11.0      0      0                2699   18.7875        C
# 732    male     0      0      0              239855    0.0000        S
# 733    male  23.0      0      0               28425   13.0000        S
# 734    male  23.0      0      0              233639   13.0000        S
# 735    male  28.5      0      0               54636   16.1000        S
# 736  female  48.0      1      3          W./C. 6608   34.3750        S
# 737    male  35.0      0      0            PC 17755  512.3292        C
# 738    male     0      0      0              349201    7.8958        S
# 739    male     0      0      0              349218    7.8958        S
# 740    male     0      0      0               16988   30.0000        S
# 741    male  36.0      1      0               19877   78.8500        S
# 742  female  21.0      2      2            PC 17608  262.3750        C
# 743    male  24.0      1      0              376566   16.1000        S
# 744    male  31.0      0      0   STON/O 2. 3101288    7.9250        S
# 745    male  70.0      1      1           WE/P 5735   71.0000        S
# 746    male  16.0      1      1           C.A. 2673   20.2500        S
# 747  female  30.0      0      0              250648   13.0000        S
# 748    male  19.0      1      0              113773   53.1000        S
# 749    male  31.0      0      0              335097    7.7500        Q
# 750  female   4.0      1      1               29103   23.0000        S
# 751    male   6.0      0      1              392096   12.4750        S
# 752    male  33.0      0      0              345780    9.5000        S
# 753    male  23.0      0      0              349204    7.8958        S
# 754  female  48.0      1      2              220845   65.0000        S
# 755    male  0.67      1      1              250649   14.5000        S
# 756    male  28.0      0      0              350042    7.7958        S
# 757    male  18.0      0      0               29108   11.5000        S
# 758    male  34.0      0      0              363294    8.0500        S
# 759  female  33.0      0      0              110152   86.5000        S
# 760    male     0      0      0              358585   14.5000        S
# 761    male  41.0      0      0    SOTON/O2 3101272    7.1250        S
# 762    male  20.0      0      0                2663    7.2292        C
# 763  female  36.0      1      2              113760  120.0000        S
# 764    male  16.0      0      0              347074    7.7750        S
# 765  female  51.0      1      0               13502   77.9583        S
# 766    male     0      0      0              112379   39.6000        C
# 767  female  30.5      0      0              364850    7.7500        Q
# 768    male     0      1      0              371110   24.1500        Q
# 769    male  32.0      0      0                8471    8.3625        S
# 770    male  24.0      0      0              345781    9.5000        S
# 771    male  48.0      0      0              350047    7.8542        S
# 772  female  57.0      0      0         S.O./P.P. 3   10.5000        S
# 773    male     0      0      0                2674    7.2250        C
# 774  female  54.0      1      3               29105   23.0000        S
# 775    male  18.0      0      0              347078    7.7500        S
# 776    male     0      0      0              383121    7.7500        Q
# 777  female   5.0      0      0              364516   12.4750        S
# 778    male     0      0      0               36865    7.7375        Q
# 779  female  43.0      0      1               24160  211.3375        S
# 780  female  13.0      0      0                2687    7.2292        C
# 781  female  17.0      1      0               17474   57.0000        S
# 782    male  29.0      0      0              113501   30.0000        S
# 783    male     0      1      2          W./C. 6607   23.4500        S
# 784    male  25.0      0      0  SOTON/O.Q. 3101312    7.0500        S
# 785    male  25.0      0      0              374887    7.2500        S
# 786  female  18.0      0      0             3101265    7.4958        S
# 787    male   8.0      4      1              382652   29.1250        Q
# 788    male   1.0      1      2           C.A. 2315   20.5750        S
# 789    male  46.0      0      0            PC 17593   79.2000        C
# 790    male     0      0      0               12460    7.7500        Q
# 791    male  16.0      0      0              239865   26.0000        S
# 792  female     0      8      2            CA. 2343   69.5500        S
# 793    male     0      0      0            PC 17600   30.6958        C
# 794    male  25.0      0      0              349203    7.8958        S
# 795    male  39.0      0      0               28213   13.0000        S
# 796  female  49.0      0      0               17465   25.9292        S
# 797  female  31.0      0      0              349244    8.6833        S
# 798    male  30.0      0      0                2685    7.2292        C
# 799  female  30.0      1      1              345773   24.1500        S
# 800    male  34.0      0      0              250647   13.0000        S
# 801  female  31.0      1      1          C.A. 31921   26.2500        S
# 802    male  11.0      1      2              113760  120.0000        S
# 803    male  0.42      0      1                2625    8.5167        C
# 804    male  27.0      0      0              347089    6.9750        S
# 805    male  31.0      0      0              347063    7.7750        S
# 806    male  39.0      0      0              112050    0.0000        S
# 807  female  18.0      0      0              347087    7.7750        S
# 808    male  39.0      0      0              248723   13.0000        S
# 809  female  33.0      1      0              113806   53.1000        S
# 810    male  26.0      0      0                3474    7.8875        S
# 811    male  39.0      0      0           A/4 48871   24.1500        S
# 812    male  35.0      0      0               28206   10.5000        S
# 813  female   6.0      4      2              347082   31.2750        S
# 814    male  30.5      0      0              364499    8.0500        S
# 815    male     0      0      0              112058    0.0000        S
# 816  female  23.0      0      0    STON/O2. 3101290    7.9250        S
# 817    male  31.0      1      1     S.C./PARIS 2079   37.0042        C
# 818    male  43.0      0      0              C 7075    6.4500        S
# 819    male  10.0      3      2              347088   27.9000        S
# 820  female  52.0      1      1               12749   93.5000        S
# 821    male  27.0      0      0              315098    8.6625        S
# 822    male  38.0      0      0               19972    0.0000        S
# 823  female  27.0      0      1              392096   12.4750        S
# 824    male   2.0      4      1             3101295   39.6875        S
# 825    male     0      0      0              368323    6.9500        Q
# 826    male     0      0      0                1601   56.4958        S
# 827    male   1.0      0      2     S.C./PARIS 2079   37.0042        C
# 828    male     0      0      0              367228    7.7500        Q
# 829  female  62.0      0      0              113572   80.0000        U
